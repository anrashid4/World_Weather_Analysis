# %%
# Import the dependencies.
import pandas as pd
import gmaps
import gmaps.datasets
import requests
# Import the API key.
#from config import g_key
from config import g_key
import traceback

# %%
iten_cities_df = pd.read_csv("weather_data/WeatherPy_vacation.csv")

# %%
pd.set_option('display.max_rows', None)
merged_directions_df
# Out:
#                       City Country  Max Temp Current Description    Lat  \
# 0                 Manicore      BR     80.60        thunderstorm  -5.81
# 1             San Patricio      MX     75.20           clear sky  19.22
# 2                  Salalah      OM     82.40    scattered clouds  17.02
# 3                   Tumpat      MY     80.60          few clouds   6.20
# 4                   Padang      ID     78.73          few clouds  -0.95
# 5                  Yenagoa      NG     75.58     overcast clouds   4.92
# 6                    Vaini      TO     84.20    scattered clouds -21.20
# 7                  Rikitea      PF     77.07     overcast clouds -23.12
# 8                Mahebourg      MU     75.20    scattered clouds -20.41
# 9          Bambous Virieux      MU     75.20    scattered clouds -20.34
# 10                    Hilo      US     82.40           clear sky  19.73
# 11                   Kapaa      US     80.60           clear sky  22.08
# ...

# %%
Hotel1 = iten_cities_df.loc[itn_cities_df["City"] == "San Patricio"].copy()

# %%
Hotel1
# Out:
#            City Country  Max Temp Current Description    Lat    Lng  \
# 1  San Patricio      MX      75.2           clear sky  19.22 -104.7
#
#           Hotel Name
# 1  Hotel Cabo Blanco

# %%
San_Patricio = Hotel1["Lat"][1], Hotel1["Lng"][1]
San_Patricio
# Out:
# (19.22, -104.7)

# %%
Hotel2 = iten_cities_df.loc[itn_cities_df["City"] == "Spring Hill"].copy()

# %%
Hotel2
# Out:
#            City Country  Max Temp Current Description    Lat    Lng  \
# 16  Spring Hill      US      86.0    scattered clouds  28.48 -82.53
#
#                              Hotel Name
# 16  Room of The world By traveline Plus

# %%
Spring_Hill = Hotel2["Lat"][16], Hotel2["Lng"][16]

Spring_Hill
# Out:
# (28.48, -82.53)

# %%
Hotel3 = iten_cities_df.loc[itn_cities_df["City"] == "Isla Mujeres"].copy()

# %%
Hotel3
# Out:
#             City Country  Max Temp Current Description    Lat    Lng  \
# 38  Isla Mujeres      MX      82.4    scattered clouds  21.23 -86.73
#
#                     Hotel Name
# 38  Hotel La Joya Isla Mujeres

# %%
Isla_Mujeres = Hotel3["Lat"][38], Hotel3["Lng"][38]

Isla_Mujeres
# Out:
# (21.23, -86.73)

# %%
Hotel4 = iten_cities_df.loc[itn_cities_df["City"] == "Cabo San Lucas"].copy()

# %%
Hotel4
# Out:
#               City Country  Max Temp Current Description    Lat     Lng  \
# 48  Cabo San Lucas      MX      77.0           clear sky  22.89 -109.91
#
#                 Hotel Name
# 48  Hotel Tesoro Los Cabos

# %%
Cabo_San_Lucas = Hotel4["Lat"][48], Hotel4["Lng"][48]

Cabo_San_Lucas
# Out:
# (22.89, -109.91)

# %%
import gmaps
import gmaps.datasets
import requests

# %%
gmaps.configure(api_key=g_key)
fig = gmaps.figure()
SanPatricio_to_Cabo_San_Lucas = gmaps.directions_layer(
        San_Patricio, Cabo_San_Lucas, waypoints=[Spring_Hill, Isla_Mujeres],
        travel_mode='DRIVING',)
fig.add_layer(SanPatricio_to_Cabo_San_Lucas)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
merged_directions_df = pd.concat([Hotel1, Hotel2, Hotel3, Hotel4])
merged_directions_df
# Out:
#               City Country  Max Temp Current Description    Lat     Lng  \
# 1     San Patricio      MX      75.2           clear sky  19.22 -104.70
# 16     Spring Hill      US      86.0    scattered clouds  28.48  -82.53
# 38    Isla Mujeres      MX      82.4    scattered clouds  21.23  -86.73
# 48  Cabo San Lucas      MX      77.0           clear sky  22.89 -109.91
#
#                              Hotel Name
# 1                     Hotel Cabo Blanco
# 16  Room of The world By traveline Plus
# 38           Hotel La Joya Isla Mujeres
# 48               Hotel Tesoro Los Cabos

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# %%
hotel_info = [info_box_template.format(**row) for index, row in merged_directions_df.iterrows()]

# %%
#map
locations = merged_directions_df[["Lat", "Lng"]]
cities = merged_directions_df["City"]
current_weather = iten_cities_df[["Current Description", "Max Temp"]]
country = merged_directions_df["Country"]

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
